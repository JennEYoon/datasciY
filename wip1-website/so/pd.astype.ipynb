# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\python\\conda3\\lib\\site-packages\\pandas\\__init__.py'>

# %%
mydic = {
    "name": ['Alice', 'Tommy', 'Jane'],
    "age": [9, 21, 22],
    "height": [3.6, 6.1, 5.5],
}

# %%
mydic
# Out:
# {'name': ['Alice', 'Tommy', 'Jane'],
#  'age': [9, 21, 22],
#  'height': [3.6, 6.1, 5.5]}

# %%
type(mydic)
# Out:
# dict

# %%
df = pd.DataFrame(data = mydic)

# %%
df
# Out:
#     name  age  height
# 0  Alice    9     3.6
# 1  Tommy   21     6.1
# 2   Jane   22     5.5

# %%
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-09616d73ed79> in <module>
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
df.dtypes
# Out:
# name       object
# age         int64
# height    float64
# dtype: object

# %%
print(df)
# Out:
#     name  age  height
# 0  Alice    9     3.6
# 1  Tommy   21     6.1
# 2   Jane   22     5.5

# %%
df.age.astype('float64')
# Out:
# 0     9.0
# 1    21.0
# 2    22.0
# Name: age, dtype: float64

# %%
df
# Out:
#     name  age  height
# 0  Alice    9     3.6
# 1  Tommy   21     6.1
# 2   Jane   22     5.5

# %%
df.dtypes
# Out:
# name       object
# age         int64
# height    float64
# dtype: object

# %%
df.age.astype('float64', copy=False)
# Out:
# 0     9.0
# 1    21.0
# 2    22.0
# Name: age, dtype: float64

# %%
df
# Out:
#     name  age  height
# 0  Alice    9     3.6
# 1  Tommy   21     6.1
# 2   Jane   22     5.5

# %%
df.dtypes
# Out:
# name       object
# age         int64
# height    float64
# dtype: object

# %%
df.age = df.age.astype('float64')

# %%
df.age
# Out:
# 0     9.0
# 1    21.0
# 2    22.0
# Name: age, dtype: float64

# %%
df.dtypes
# Out:
# name       object
# age       float64
# height    float64
# dtype: object

# %%
df.name = df.name.astype('str')

# %%
df.dtypes
# Out:
# name       object
# age       float64
# height    float64
# dtype: object

# %%
df
# Out:
#     name   age  height
# 0  Alice   9.0     3.6
# 1  Tommy  21.0     6.1
# 2   Jane  22.0     5.5

# %%
df.height = df.height.astype('int32')

# %%
df
# Out:
#     name   age  height
# 0  Alice   9.0       3
# 1  Tommy  21.0       6
# 2   Jane  22.0       5

# %%
df.dtypes
# Out:
# name       object
# age       float64
# height      int32
# dtype: object

# %%
df.age = df.age.astype('str')

# %%
df
# Out:
#     name   age  height
# 0  Alice   9.0       3
# 1  Tommy  21.0       6
# 2   Jane  22.0       5

# %%
df.dtypes
# Out:
# name      object
# age       object
# height     int32
# dtype: object

# %%
df
# Out:
#     name   age  height
# 0  Alice   9.0       3
# 1  Tommy  21.0       6
# 2   Jane  22.0       5

# %%
df['height'] = df['height'].astype('float32')

# %%
df
# Out:
#     name   age  height
# 0  Alice   9.0     3.0
# 1  Tommy  21.0     6.0
# 2   Jane  22.0     5.0

# %%
df.dtypes
# Out:
# name       object
# age        object
# height    float32
# dtype: object
