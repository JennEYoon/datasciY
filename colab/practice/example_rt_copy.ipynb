# %% [markdown]
# # Example notebook for hosting on mybinder.org
# June 15, 2020  7:53 PM EST
# On Github datasciY repo.

# %% [markdown]
# ### MyBinder build environment
# to add mybinder badge
#
# environment.yml has to be at root level.
# Re-built image, launch takes very long time.
#    \-

# %%
# Add Opin in Binder badge.

# %% [markdown]
# ### Google Colab link   - Done
# Used html table to make into a box.
# To add black outline around table somehow.

# %% [markdown]
# <table align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/jenneyoon/datasciy/blob/main/example_rt.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
# </table>

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/jenneyoon/datasciy/blob/main/example_rt.ipynb">
#     <img align="left" src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/jenneyoon/datasciy/blob/main/example_rt.ipynb">
#   <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>   Open in Colab</a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/jenneyoon/datasciy/blob/main/example_rt.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# %matplotlib inline

# %% [markdown]
# ### 1. Matplotlib 3D plots

# %%
# 3D data  
def f(x, y):
    return np.cos(np.sqrt(x**2 + y**2))

x = np.linspace(-4, 4, 36)
y = np.linspace(-4, 4, 36)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
# OO Style, set plot
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 60, cmap='RdBu')
ax.set(xlabel='X', ylabel='Y', zlabel='Z', title='Contour Plot 3D')
# Out:
# [Text(0.5, 0, 'Z'),
#  Text(0.5, 0, 'Y'),
#  Text(0.5, 0, 'X'),
#  Text(0.5, 0.92, 'Contour Plot 3D')]

# %% [markdown]
# ### 2. Overploting Histograms

# %%
# data for 3 histograms, randomly generated  
x1 = np.random.normal(0, 0.5, 200)
x2 = np.random.normal(-2, 1, 200)
x3 = np.random.normal(3, 1.6, 200)

# %%
plt.style.use('seaborn-whitegrid')
kwargs = dict(histtype='stepfilled', alpha=0.4, density=True, bins=25)
plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
plt.title('Three Histograms')
plt.xlabel('X data')
plt.ylabel('Y count');

# %%
# !python --version
import datetime as dt
print(dt.date.today())
print(dt.datetime.now())
# Out:
# Python 3.8.3
# 2020-06-15
# 2020-06-15 23:53:43.306796
